# %% [markdown]
# # HUDM 5001 — Programming for Data Science
# ## Session 03 · Python Intro: Data Types, Variables & Expressions
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/youmilab/hudm5001/blob/main/colab_notebooks/03_data_types_variables_expressions.ipynb)
#
# **Teachers College, Columbia University** &nbsp;·&nbsp; Week 3 &nbsp;·&nbsp; Based on the Fall 2025 syllabus
# *Last updated: June 2026*
#
# > ▶️ **How to open this notebook in Google Colab** — pick whichever is easiest:
# > 1. **From Google Drive:** put this `.ipynb` in your Drive, right-click it → *Open with* → *Google Colaboratory*.
# > 2. **Upload:** go to [colab.research.google.com](https://colab.research.google.com) → *File ▸ Upload notebook* → choose this file.
# > 3. **From GitHub:** click the **Open in Colab** badge above (works once the notebook is pushed to the course repo).
# >
# > Then **run the Setup cell first** (▶ or `Shift+Enter`). Everything else runs top-to-bottom.
#
# Welcome to Python! Today we learn the vocabulary of the language: how to **store values in variables** and the **built-in data types** Python gives us — numbers, text, and the four core containers (list, tuple, set, dict). Everything else this semester builds on these foundations.

# %% [markdown]
# ---
# ## 1. Big Picture
#
# ### 🎯 Learning Objectives
# By the end of this session you will be able to:
# - Create variables following Python's **naming rules**, and inspect them with `type()`.
# - Use the core **scalar** types: `bool`, `int`, `float`, `str`.
# - Use the core **container** types: `list`, `tuple`, `set`, `dict`, and `range`.
# - Distinguish **mutable** vs **immutable** types and explain why it matters.
# - Index, slice, and loop over strings and lists; format strings with f-strings and `.format()`.
# - Convert between types and predict when a conversion will fail.
#
# ### ✅ Prerequisites
# - A running Python session (this Colab notebook — just run the Setup cell).
# - Weeks 1–2 (shell + GitHub).
#
# ### 🧩 Key Concepts
# `variable`  `expression`  `bool`  `int`  `float`  `str`  `list`  `tuple`  `set`  `dict`  `range`  `mutable`  `immutable`  `indexing`  `slicing`
#
# ### 📖 Reading
# - McKinney, *Python for Data Analysis*, Chapters 1 & 2
#
# ### 🗺️ Today's Agenda
# 1. Variables & expressions: naming, assignment, `type()`
# 2. Booleans and numbers (int, float)
# 3. Strings: indexing, slicing, methods, formatting
# 4. Containers: list, tuple, set, dict
# 5. Ranges and type conversions

# %% [markdown]
# ---
# ## ▶️ Setup — run this cell first
# This installs anything Colab is missing, imports the libraries we'll use, and sets `DATA_BASE`
# (the address of the course data on GitHub).

# %%
# === SETUP — run me first! ===
# Pure-Python session — only the standard library.
import sys
print('Python', sys.version.split()[0])

# Course data is read straight from the public course repo on GitHub,
# so these notebooks run anywhere (Colab, Jupyter, locally) with no downloads.
DATA_BASE = "https://raw.githubusercontent.com/youmilab/hudm5001/main/"
print("Setup complete ✅  — data base URL:", DATA_BASE)

# %% [markdown]
# ---
# ## 2. Content
#
# ### 2.1 Variables & expressions
# A **variable** is a name that refers to a value. You create one with the assignment operator `=`.
# Variable names can be any length but must **start with a letter or underscore**, followed by letters, numbers,
# or underscores — and can't be a reserved keyword.

# %%
# valid assignments
epoch = 20            # an int
model = 'gbt'         # a str
print('epoch =', epoch, '| model =', model)

# multiple assignment at once
x = y = z = 5         # all three get 5
a, b = 3, 4           # 'unpacking': a=3, b=4
print(x, y, z, '|', a, b)

# %%
# These are INVALID names — uncomment one at a time to see the error
# 1_model = 2     # can't start with a digit
# return = 3      # 'return' is a reserved keyword

# %% [markdown]
# `type()` reports a value's data type. Use `del` to delete a variable.

# %%
print(type('ERROR'))
print(type(0.55))
print(type({'cat': 'persian', 'bird': 'parrot'}))

del model        # remove the variable
# print(model)   # would now raise NameError

# %% [markdown]
# #### ✏️ Try It Yourself — Exercise 1
# Given `x = 5`, explain in a comment how `x = 5` differs from `x == 5`. Then print the `type()` of the expression `x == 5`.

# %%
# Your code here

# %% [markdown]
# <details>
# <summary>▶ Show solution</summary>
#
# ```python
# # `x = 5` ASSIGNS 5 to x (a statement).
# # `x == 5` TESTS whether x equals 5 and returns a bool (an expression).
# x = 5
# print(type(x == 5))   # <class 'bool'>
# ```
#
# </details>

# %% [markdown]
# #### ✏️ Try It Yourself — Exercise 2
# For each candidate, say (in a comment) whether it's a **valid** Python variable name: `aws`, `aws-instance`, `_aws_instance`, `3rd_instance`.

# %%
# Your code here

# %% [markdown]
# <details>
# <summary>▶ Show solution</summary>
#
# # aws            -> valid
# # aws-instance   -> INVALID (hyphen not allowed)
# # _aws_instance  -> valid (underscore start is fine)
# # 3rd_instance   -> INVALID (starts with a digit)
#
# </details>

# %% [markdown]
# ### 2.2 Booleans
# A **boolean** is either `True` or `False`. Booleans power every decision your code makes. Check a value's type
# with `isinstance(value, type)`.

# %%
cache = True
print(type(cache))
print(isinstance(cache, bool))   # True

# %% [markdown]
# Compound conditions use `and`, `or`, `not`. Python **short-circuits**: in `A and B`, if `A`
# is `False`, `B` is never evaluated.

# %%
oome = False
cache = True
if oome and cache:
    print("both true")
else:
    print("short-circuited: because oome is False, cache was never checked")

# %% [markdown]
# ### 2.3 Numbers: `int` and `float`
# - **`int`** — whole numbers (`21`, `-4`, `1000000`).
# - **`float`** — numbers with a decimal point (`0.95`, `-3.14`).

# %%
epoch = 21
f1_score = 0.95
print(epoch, type(epoch))
print(f1_score, type(f1_score))
print('is epoch an int? ', isinstance(epoch, int))
print('is f1 a float?   ', isinstance(f1_score, float))

# %% [markdown]
# ### 2.4 Strings
# A **string** (`str`) is text — a sequence of characters in single or double quotes. Strings are **indexable**
# (0-based) and **sliceable**, but **immutable** (you can't change a character in place).

# %%
status = 'success'
print(type(status))
print('first char :', status[0])      # 's'
print('first two  :', status[:2])     # 'su'
print('last two   :', status[-2:])    # 'ss'
print('length     :', len(status))

# %%
# Handy string methods
print(status.upper())
print(status.startswith('a'))   # False
print(status.endswith('s'))     # True
print('  trim me  '.strip())    # remove surrounding whitespace

# %% [markdown]
# **Immutability** — this fails because strings can't be edited in place:

# %%
status = 'success'
# status[0] = 'X'        # TypeError: 'str' object does not support item assignment
status = 'Xuccess'        # but REASSIGNING the whole variable is fine
print(status)

# %% [markdown]
# **Building strings.** Concatenate with `+`, or (better) insert values with **f-strings** or
# `.format()`.

# %%
path = '/Users/ys2952/repo/hudm5001/'
file = 'iris.csv'
print(path + file)                       # concatenation

epoch, loss = 3, 0.12
print(f'Epoch: {epoch}, loss: {loss}')                 # f-string (modern, preferred)
print('Epoch: {}, loss: {}'.format(epoch, loss))       # .format() (also common)

# %% [markdown]
# #### ✏️ Try It Yourself — Exercise 3
# Define `mystr = 'python'`. Print (a) the string in UPPERCASE, (b) its first 3 characters, and (c) a sentence like *"python has 6 letters"* using an f-string and `len()`.

# %%
# Your code here

# %% [markdown]
# <details>
# <summary>▶ Show solution</summary>
#
# ```python
# mystr = 'python'
# print(mystr.upper())
# print(mystr[:3])
# print(f'{mystr} has {len(mystr)} letters')
# ```
#
# </details>

# %% [markdown]
# ### 2.5 Lists — the workhorse container
# A **list** is an *ordered, mutable* collection written in `[ ]`. It can hold mixed types, be indexed and
# sliced, grown, and looped over.

# %%
financial_derivatives = ['futures', 'swaps', 'options']
print(type(financial_derivatives))
print('first      :', financial_derivatives[0])
print('first 3 chars of first item:', financial_derivatives[0][:3])

# lists are MUTABLE: change, append, extend
financial_derivatives[1] = 'forwards'      # change an element
financial_derivatives.append('bonds')      # add to the end
print(financial_derivatives)

# %% [markdown]
# Loop over a list directly, or use **`enumerate`** to get the index *and* the value.

# %%
for deriv in financial_derivatives:
    print(deriv, '->', len(deriv), 'chars')

print('--- with enumerate ---')
for ix, deriv in enumerate(financial_derivatives):
    print(ix, deriv)

# %%
# Lists can be concatenated with +
variables = ['x1', 'x2'] + ['x3', 'x4']
print(variables)

# %% [markdown]
# #### ✏️ Try It Yourself — Exercise 4
# Create a list `mylist` with one each of: an integer, a float, a bool, and a string. Then write a for-loop that prints each value next to its `type()`.

# %%
# Your code here

# %% [markdown]
# <details>
# <summary>▶ Show solution</summary>
#
# ```python
# mylist = [4, 2.2, False, 'fancy']
# for val in mylist:
#     print(val, type(val))
# ```
#
# </details>

# %% [markdown]
# ### 2.6 Tuples — like lists, but frozen
# A **tuple** is an *ordered, **immutable*** collection, written with `( )` (or just commas). Use tuples for
# fixed groupings that shouldn't change.

# %%
coffees = ('brazilian', 'costa_rican', 'colombian')
print(type(coffees), '| first:', coffees[0])

# parentheses are optional — commas make the tuple
grab_bag = 4, 'EHR', ['year', 'in', 'review']
print(grab_bag)

# coffees[0] = 'kenyan'    # TypeError: tuples are immutable
for ix, coffee in enumerate(coffees):
    print(ix, coffee)

# %% [markdown]
# ### 2.7 Sets — unique, unordered
# A **set** holds *unique*, *unordered* values in `{ }`. Great for de-duplicating and for fast membership tests
# with `in`. (Note: `{}` alone makes an empty **dict**, not a set — use `set()`.)

# %%
peanuts = {'snoopy', 'snoopy', 'woodstock'}
print(peanuts)                      # duplicates removed automatically
print('snoopy' in peanuts)          # membership test -> True

set1 = {'python', 'R'}
set2 = {'R', 'julia'}
print('union       :', set1.union(set2))           # everything
print('intersection:', set1.intersection(set2))    # in both

# %% [markdown]
# ### 2.8 Dictionaries — key → value lookups
# A **dict** maps **keys** to **values** in `{key: value}`. It's the most important container for data work
# (think: column name → column, or id → record).

# %%
airports = {'LAGUARDIA': 'LGA', 'LOGAN': 'BOS', 'NANTUCKET': 'ACK'}
print(airports['LOGAN'])                 # look up by key -> 'BOS'
print(airports.get('KENNEDY'))           # .get() returns None instead of erroring on a missing key

airports['DULLES'] = 'IAD'               # add / update a pair
print(airports.keys())
print(airports.values())

# %%
# Loop over keys and values together with .items()
for name, code in airports.items():
    print(f'{name:12s} -> {code}')

# %% [markdown]
# #### ✏️ Try It Yourself — Exercise 5
# Build a dict `name_age` with three name→age pairs. Print one person's age by key, then loop with `.items()` to print `"<name> is <age>"` for everyone.

# %%
# Your code here

# %% [markdown]
# <details>
# <summary>▶ Show solution</summary>
#
# ```python
# name_age = {'greg': 15, 'annabel': 22, 'joaquin': 19}
# print(name_age['annabel'])
# for name, age in name_age.items():
#     print(f'{name} is {age}')
# ```
#
# </details>

# %% [markdown]
# ### 2.9 Ranges and type conversions
# **`range(start, stop, step)`** generates a sequence of integers (stop is *exclusive*) — most often used to drive
# loops. **Type conversions** use the type's name as a function: `int()`, `float()`, `str()`, `list()`.

# %%
for n in range(1, 11, 2):    # 1, 3, 5, 7, 9  (stop=11 excluded)
    print(n, end=' ')
print()

# conversions
print(int(3.8))        # 3   (truncates toward zero)
print(float('3.8'))    # 3.8 (string -> float)
print(str(3.8))        # '3.8'
# print(int('3.8'))    # ValueError: can't go string-decimal -> int directly
print(int(float('3.8')))   # ...do it in two steps instead -> 3

# %% [markdown]
# #### ✏️ Try It Yourself — Exercise 6
# Use a single `for` loop over `range(-5, 5, 2)` to print each number and whether it is even (`n % 2 == 0`).

# %%
# Your code here

# %% [markdown]
# <details>
# <summary>▶ Show solution</summary>
#
# ```python
# for n in range(-5, 5, 2):
#     print(n, 'even' if n % 2 == 0 else 'odd')
# ```
#
# </details>

# %% [markdown]
# ---
# ## 3. Conclusions & Key Takeaways
# - **Variables** name values; check types with `type()` / `isinstance()`.
# - **Scalars:** `bool`, `int`, `float`, `str`. **Containers:** `list`, `tuple`, `set`, `dict`, plus `range`.
# - **Mutable** (changeable in place): `list`, `set`, `dict`. **Immutable**: `int`, `float`, `bool`, `str`, `tuple`.
# - Strings and lists are **0-indexed** and support slicing `[start:stop]`; `stop` is exclusive.
# - Use **f-strings** (`f'{x}'`) for readable string building.
# - **Dicts** (key→value) and **lists** are the two containers you'll use most in data science.
# - Conversions can fail — e.g. `int('3.8')` errors; go `int(float('3.8'))` instead.
#
# ### 🧾 Quick Reference
# | Type | Example | Mutable? | Ordered? |
# |---|---|:--:|:--:|
# | `bool` | `True` | – | – |
# | `int` / `float` | `21` / `0.95` | no | – |
# | `str` | `'success'` | **no** | yes |
# | `list` | `['a', 5]` | **yes** | yes |
# | `tuple` | `('a', 5)` | no | yes |
# | `set` | `{'a', 'b'}` | yes | no |
# | `dict` | `{'k': 'v'}` | yes | yes (insertion) |
#
# ### ⏭️ Coming Up Next
# **Week 4 — Operators, Input/Output, and NumPy.** We start computing with our data and meet NumPy arrays. Read McKinney Ch 4.
#
# ### 📌 This Week's Assignment
# Programming assignment + take-home quiz on data types — see Canvas/GitHub.
#
# > 💡 **Tip:** make a copy in Colab (*File ▸ Save a copy in Drive*) and add your own notes — experimenting in the code cells is the fastest way to learn.
