# %% [markdown]
# # Programming for Data Science — Mini Session 02
# ## Assignment: Operators, Input/Output & NumPy
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/cgpan/humd5001_mini/blob/main/assignment/02_Operators_IO_Numpy_Assignment.ipynb)
#
# [**Chenguang Pan**](https://cpan.ai/), [**Youmi Lab**](https://youmilab.ai/)
# **Teachers College, Columbia University**
#
# This assignment goes with the in-class notebook **`02_Operators_IO_Numpy.ipynb`**. Reading about code is one thing; writing it is another — so open a cell and start typing. That is where the learning actually happens.

# %% [markdown]
# ---
# ### 📋 How this assignment works
#
# - **Run on Google Colab.** Open this notebook with the badge above, then *File ▸ Save a copy in Drive* so you have your own copy to edit.
# - **Scope.** Everything here builds on **Sessions 01 and 02**. You still will not need `for` loops, `if` statements, or your own functions (`def`) — and please do not use them. NumPy's boolean indexing does the filtering that a loop-plus-`if` would, which is exactly the point.
# - **Three parts:**
#   1. **Part A — Multiple Choice** (10 questions): check your understanding.
#   2. **Part B — Basic Exercises** (6 questions): short drills, one Session-02 topic each.
#   3. **Part C — Integrated Challenges** (4 questions): bigger tasks that pull together what you learned in *both* sessions.
# - **Difficulty** runs from ★☆☆☆☆ (warm-up) to ★★★★★ (make-you-think). The **Skills** line names the tools each question is really about.
# - Use **clear variable names** and drop a **comment** on the tricky lines. Six months from now, that comment is a gift to yourself.
#
# **Total: 100 points** — Part A: 20 · Part B: 30 · Part C: 50.

# %% [markdown]
# ---
# ### ✍️ Before you start
# Put your name in the next cell, then run the setup cell right after it.

# %%
student_name = ""   # <-- type your name between the quotes
print("Submission by:", student_name)

# %%
# === SETUP — run me first! ===
import numpy as np
import pandas as pd
import json, os

# The iris dataset lives in the public course repo, so you can read it straight
# from the web (no download needed) — the same trick we used for the wine data in class.
IRIS_URL = "https://raw.githubusercontent.com/cgpan/humd5001_mini/main/assets/iris.csv"

print("NumPy", np.__version__, "| pandas", pd.__version__)
print("Setup complete ✅")

# %% [markdown]
# ---
# ## Part A — Multiple Choice  *(2 points each, 20 total)*
#
# Reason each one out — you should not need to run any code for Part A. When you are done, record your letters in the answer dictionary at the end of this part.

# %% [markdown]
# #### Question A1
# **Difficulty:** ★☆☆☆☆  **Skills:** `//` floor division
#
# What is the value of `17 // 5`?
#
# - **A.** `3.4`
# - **B.** `3`
# - **C.** `4`
# - **D.** `2`

# %% [markdown]
# #### Question A2
# **Difficulty:** ★☆☆☆☆  **Skills:** `%` modulus
#
# Which expression is a reliable test for whether an integer `n` is **even**?
#
# - **A.** `n // 2 == 0`
# - **B.** `n % 2 == 0`
# - **C.** `n / 2 == 0`
# - **D.** `n ** 2 == 0`

# %% [markdown]
# #### Question A3
# **Difficulty:** ★★☆☆☆  **Skills:** true division, `type()`
#
# What does `type(8 / 2)` return?
#
# - **A.** `<class 'int'>`
# - **B.** `<class 'float'>`
# - **C.** `<class 'str'>`
# - **D.** `<class 'bool'>`

# %% [markdown]
# #### Question A4
# **Difficulty:** ★★★☆☆  **Skills:** comparison + logical `and`
#
# What does the code below print? *(Just think — no need to run.)*
#
# ```python
# print((3 > 1) and (1 > 3))
# ```
#
# - **A.** `True`
# - **B.** `False`
# - **C.** `None`
# - **D.** `Error`

# %% [markdown]
# #### Question A5
# **Difficulty:** ★★★☆☆  **Skills:** `is` vs `==`
#
# After running the lines below, which pair of results is correct?
#
# ```python
# a = [1, 2, 3]
# b = [1, 2, 3]
# ```
#
# - **A.** `a == b` → `True`,  `a is b` → `False`
# - **B.** `a == b` → `False`, `a is b` → `True`
# - **C.** `a == b` → `True`,  `a is b` → `True`
# - **D.** `a == b` → `False`, `a is b` → `False`

# %% [markdown]
# #### Question A6
# **Difficulty:** ★★☆☆☆  **Skills:** membership `in` on a `dict`
#
# Given `grades = {"Ann": 90, "Bob": 85}`, what do `"Ann" in grades` and `90 in grades` return, in that order?
#
# - **A.** `True` and `True`
# - **B.** `True` and `False`
# - **C.** `False` and `True`
# - **D.** `False` and `False`

# %% [markdown]
# #### Question A7
# **Difficulty:** ★★☆☆☆  **Skills:** file modes in `open()`
#
# You want to **add** new lines to the end of an existing file *without* erasing what is already there. Which mode should you open it with?
#
# - **A.** `'r'`
# - **B.** `'w'`
# - **C.** `'a'`
# - **D.** `'x'`

# %% [markdown]
# #### Question A8
# **Difficulty:** ★★★☆☆  **Skills:** `json.dump` / `json.load`
#
# You saved a Python dictionary to a file with `json.dump`. Which function reads it back into a Python dictionary?
#
# - **A.** `json.read`
# - **B.** `json.parse`
# - **C.** `json.load`
# - **D.** `json.open`

# %% [markdown]
# #### Question A9
# **Difficulty:** ★★☆☆☆  **Skills:** NumPy vectorization
#
# Both lines below use `* 2`, but they do **not** do the same thing. What does each one print?
#
# ```python
# print([1, 2, 3] * 2)
# print(np.array([1, 2, 3]) * 2)
# ```
#
# - **A.** `[2, 4, 6]` then `[2 4 6]`
# - **B.** `[1, 2, 3, 1, 2, 3]` then `[2 4 6]`
# - **C.** `[1, 2, 3, 1, 2, 3]` then `[1 2 3 1 2 3]`
# - **D.** `[2, 4, 6]` then `[1 2 3 1 2 3]`

# %% [markdown]
# #### Question A10
# **Difficulty:** ★★★★☆  **Skills:** NumPy boolean indexing
#
# Given `z = np.array([5, -2, 8, -1, 3])`, what is `z[z > 0]`?
#
# - **A.** `array([ True, False,  True, False,  True])`
# - **B.** `array([5, 8, 3])`
# - **C.** `array([-2, -1])`
# - **D.** `array([5, -2, 8, -1, 3])`

# %% [markdown]
# #### ✅ Record your Part A answers
# Fill in the dictionary below so each number points to your chosen letter (for example, `1: "C"`). Yes — this is the **dictionary** skill from Session 01, doing real work.

# %%
my_mcq_answers = {
    1:  "",   # Question A1
    2:  "",   # Question A2
    3:  "",   # Question A3
    4:  "",   # Question A4
    5:  "",   # Question A5
    6:  "",   # Question A6
    7:  "",   # Question A7
    8:  "",   # Question A8
    9:  "",   # Question A9
    10: "",   # Question A10
}
print(my_mcq_answers)

# %% [markdown]
# ---
# ## Part B — Basic Exercises  *(5 points each, 30 total)*
#
# Each drill zooms in on **one topic** from Session 02. Write your answer in the empty cell under each prompt. Short is fine — focused is the goal.

# %% [markdown]
# #### Exercise B1 — Boxing up an order
# **Difficulty:** ★☆☆☆☆  **Points:** 5
# **Skills:** `//`, `%`, arithmetic, f-string
#
# A bakery made **250** cookies and packs exactly **12** cookies per box.
#
# 1. Use **floor division** (`//`) to find how many **full boxes** they can pack.
# 2. Use the **modulus** (`%`) to find how many **leftover** cookies will not fill a box.
# 3. Print both in one f-string, for example: `20 full boxes with 10 cookies left over.`

# %%
# Your code here

# %% [markdown]
# #### Exercise B2 — Who makes the shortlist?
# **Difficulty:** ★★☆☆☆  **Points:** 5
# **Skills:** comparison (`>=`), logical `and` / `or`
#
# A scholarship goes to any applicant whose **GPA is at least 3.5** *and* who has **at least 30 credits** — or, regardless of credits, to anyone with a **perfect 4.0**.
#
# ```python
# gpa = 3.6
# credits = 28
# ```
#
# 1. Store the "meets the GPA-and-credits rule" result in a variable, using `>=` and `and`.
# 2. Store the "has a perfect 4.0" result in another variable.
# 3. Combine the two with `or` and print whether this applicant makes the shortlist. (With these numbers the answer is `False`.) No `if` needed — just let the booleans speak.

# %%
# Your code here

# %% [markdown]
# #### Exercise B3 — Same value, or the same object?
# **Difficulty:** ★★★☆☆  **Points:** 5
# **Skills:** `==`, `is`, `in`, `not in`
#
# ```python
# list_a = [10, 20, 30]
# list_b = [10, 20, 30]
# list_c = list_a
# enrolled = {"HUDM5001": 3, "HUDM5122": 3}
# ```
#
# 1. Print `list_a == list_b` and `list_a is list_b`. They disagree — add a one-line comment explaining why.
# 2. Print `list_a is list_c` (this one *does* share the same object).
# 3. Use `in` to confirm `"HUDM5001"` is in `enrolled`, and `not in` to confirm `"HUDM5300"` is not. (Remember: `in` on a dict looks at its **keys**.)

# %%
# Your code here

# %% [markdown]
# #### Exercise B4 — Jotting notes to a file
# **Difficulty:** ★★☆☆☆  **Points:** 5
# **Skills:** `with open`, `.write`, `.read`
#
# 1. Using `with open(...)` in write mode, create a file called `my_notes.txt` and write **two lines**: `hello` and `data science` (put each on its own line — remember the `\n`).
# 2. In a second `with open(...)` block, read the whole file back with `.read()` and print it.

# %%
# Your code here

# %% [markdown]
# #### Exercise B5 — Saving a record as JSON
# **Difficulty:** ★★★☆☆  **Points:** 5
# **Skills:** `json.dump`, `json.load`, `os.path.exists`
#
# ```python
# student = {"name": "Ann", "major": "Learning Analytics", "scores": [90, 85, 88]}
# ```
#
# 1. Write this dictionary to `student.json` using `json.dump`.
# 2. Read it back with `json.load` into a new variable, and print the value stored under `"scores"`.
# 3. Confirm the file really landed on disk with `os.path.exists("student.json")`.

# %%
# Your code here

# %% [markdown]
# #### Exercise B6 — First steps with a NumPy array
# **Difficulty:** ★★★☆☆  **Points:** 5
# **Skills:** `np.array`, `.shape`, vectorized math, `.mean()`, boolean indexing
#
# ```python
# temps = np.array([68, 71, 65, 74, 70, 69])   # daily high temps in °F
# ```
#
# 1. Print the array's **shape**.
# 2. Build a new array of the temperatures in **Celsius** with the vectorized formula `(temps - 32) * 5 / 9`, rounded to 1 decimal (`.round(1)`).
# 3. Print the **average** Fahrenheit temperature with `.mean()`.
# 4. Using **boolean indexing**, print only the temperatures **above 70**.

# %%
# Your code here

# %% [markdown]
# ---
# ## Part C — Integrated Challenges  *(50 points total)*
#
# Now the fun part. Each task is a small but realistic problem that leans on **both** sessions — the containers and strings from Session 01, and the operators, file I/O, and NumPy from Session 02. Still no `for`, `if`, or `def`: NumPy and string methods have you covered.

# %% [markdown]
# #### Exercise C1 — Data Science — from a gradebook dict to a NumPy array
# **Difficulty:** ★★★☆☆  **Points:** 12
# **Skills:** `dict` indexing, `np.array`, vectorized math, `.mean()` / `.max()`, boolean indexing, f-string
#
# **The setting.** In Session 01 you stored scores in a dictionary. That is great for looking things up, but the moment you want *statistics*, NumPy is the better tool. Here you will move data from one into the other.
#
# ```python
# gradebook = {
#     "Maya": [88, 92, 79, 95],
#     "Liam": [75, 85, 95, 80],
#     "Noah": [100, 90, 80, 70],
# }
# ```
#
# 1. Pull out **Liam's** list of scores by its key and turn it into a NumPy array called `liam`.
# 2. Print Liam's **average** (rounded to 1 decimal) and his **highest** score, using `.mean()` and `.max()`.
# 3. The professor adds a **5-point curve** for everyone. Apply it to `liam` with vectorized addition (`liam + 5`) and print the result.
# 4. Using **boolean indexing** on the *curved* scores, print how many of Liam's scores are now **at least 90** (a boolean array's `.sum()` counts the `True`s).
# 5. Wrap up with an f-string, for example: `Liam's curved average is 88.8, and 2 of his scores are now 90+.`

# %%
# Your code here

# %% [markdown]
# #### Exercise C2 — NLP — clean a review, then save the stats
# **Difficulty:** ★★★★☆  **Points:** 12
# **Skills:** `.lower()`, `.replace()`, `.split()`, `set()`, `len()`, arithmetic, `json.dump` / `json.load`, f-string
#
# **The setting.** A text-analysis pipeline usually *ends* by saving its results so a later step can pick them up. You will clean a short review (Session 01 string work) and write the numbers out to a JSON file (Session 02 I/O).
#
# ```python
# review = "The food was good and the service was good and the price was fair"
# ```
#
# Treat `"the"`, `"was"`, and `"and"` as stop words.
#
# 1. **Lowercase** the review, `.split()` it into words, and count them with `len()` → `total_words`.
# 2. Count the **unique** words by converting the word list to a `set()` → `unique_words`.
# 3. Remove the stop words with the padding trick from class: pad the lowercased text with a leading and trailing space, then chain `.replace(" the ", " ")`, `.replace(" was ", " ")`, and `.replace(" and ", " ")`. Split the result and count what is left → `content_words`.
# 4. Compute a rough **lexical diversity** score, `unique_words / total_words`, rounded to 2 decimals.
# 5. Put these four numbers in a dictionary, **write it to `review_stats.json`** with `json.dump`, then read it back with `json.load` and print it.
# 6. Finish with an f-string: `___ words, ___ unique, ___ after cleaning. Diversity = ___.`

# %%
# Your code here

# %% [markdown]
# #### Exercise C3 — Computer Vision — an image, now as a real array
# **Difficulty:** ★★★★☆  **Points:** 13
# **Skills:** `np.array`, 2-D indexing `[row, col]`, slicing, vectorized math, boolean indexing, `.mean()`, `.shape`, f-string
#
# **The setting.** In Session 01 we said an image is "just a grid of numbers" and stored it as a list of lists. NumPy is what real image code actually uses — the whole grid becomes one array you can slice and transform at once.
#
# ```python
# image = np.array([
#     [ 10, 200,  90],
#     [255, 128,   0],
#     [ 60,  75, 240],
# ])
# ```
#
# 1. Print the image's **shape**.
# 2. Print the pixel in the **top-right corner** using `[row, col]` indexing.
# 3. Print the **middle column** with slicing (`image[:, 1]`).
# 4. **Normalize** the whole image to the 0–1 range in one shot with vectorized division (`image / 255`), rounded to 2 decimals — no loop, the entire grid at once.
# 5. Using **boolean indexing**, print how many pixels are **brighter than 100** (count the `True`s with `.sum()`).
# 6. Print the image's **average brightness** with `.mean()`, rounded to 1 decimal.
# 7. Finish with an f-string: `This image is ___ x ___ with an average brightness of ___.`

# %%
# Your code here

# %% [markdown]
# #### Exercise C4 — Real data — a first look at the iris dataset
# **Difficulty:** ★★★★★  **Points:** 13
# **Skills:** `pd.read_csv` (from a URL), `set()`, `np.array`, `.mean()` / `.max()` / `.min()`, boolean indexing, `%`, `json.dump` / `json.load`, `os.path.exists`, f-string
#
# **The setting.** This is the whole toolkit at once — read a real dataset from the web, poke at it with NumPy, and save a small summary. That is the shape of an actual analysis. The famous **iris** dataset holds 150 flowers from three species, with four measurements each. You already set `IRIS_URL` in the setup cell.
#
# 1. Read the CSV with `pd.read_csv(IRIS_URL)` into `iris`. Print its **shape** and its **column names** as a list.
# 2. The `species` column repeats a lot. Wrap it in `set(iris["species"])` to get the **unique species**, and print how many there are with `len()`.
#    *(Selecting a column by name, `iris["column"]`, works just like a dictionary lookup from Session 01.)*
# 3. Turn the `petal_length` column into a NumPy array: `petals = np.array(iris["petal_length"])`. Print its **mean** (rounded to 2), **max**, and **min**.
# 4. Using **boolean indexing**, count how many flowers have a petal length **above the mean**: `(petals > petals.mean()).sum()`.
# 5. Use the **modulus** to print whether the number of flowers is even: `len(petals) % 2 == 0`.
# 6. Build a small summary **dictionary** (number of species, mean petal length, how many above the mean), write it to `iris_summary.json` with `json.dump`, read it back with `json.load`, and confirm it is there with `os.path.exists`.
# 7. End with an f-string: `iris has ___ flowers across ___ species; ___ have longer-than-average petals.`

# %%
# Your code here

# %% [markdown]
# ---
# ## 📤 Submission
#
# 1. In Colab, run *Runtime ▸ Run all* and make sure every cell finishes **without errors**.
# 2. Double-check that your Part A answer dictionary is filled in.
# 3. Save or download your notebook (*File ▸ Download ▸ .ipynb*, or share your Colab link) and turn it in on **Canvas** as instructed.
#
# > 💡 Stuck on something? Re-open `02_Operators_IO_Numpy.ipynb` — and keep `01_Python_Quick_Start.ipynb` handy for the Session-01 pieces. Every tool you need is demonstrated there.
