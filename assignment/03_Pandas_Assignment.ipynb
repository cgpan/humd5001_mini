# %% [markdown]
# # Programming for Data Science — Mini Session 03
# ## Assignment: pandas
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/cgpan/humd5001_mini/blob/main/assignment/03_Pandas_Assignment.ipynb)
#
# [**Chenguang Pan**](https://cpan.ai/), [**Youmi Lab**](https://youmilab.ai/)
# **Teachers College, Columbia University**
#
# This assignment goes with the in-class notebook **`03_Pandas.ipynb`**. pandas rewards tinkering, so open a cell and start poking at the data — that is where it clicks.

# %% [markdown]
# ---
# ### 📋 How this assignment works
#
# - **Run on Google Colab.** Open this notebook with the badge above, then *File ▸ Save a copy in Drive* so you have your own copy to edit.
# - **Scope.** Everything here builds on **Sessions 01–03**. You still will not need `for` loops, `if` statements, or your own functions (`def`) — and please do not use them. pandas is **vectorized**, so a boolean mask or a `groupby` does the job a loop-and-`if` used to.
# - **Three parts:**
#   1. **Part A — Multiple Choice** (10 questions): check your understanding.
#   2. **Part B — Basic Exercises** (6 questions): short drills, one pandas idea each.
#   3. **Part C — Integrated Challenges** (4 questions): a real analysis of the **wine** dataset, start to finish.
# - **Difficulty** runs from ★☆☆☆☆ (warm-up) to ★★★★★ (make-you-think). The **Skills** line names the tools each question is really about.
# - Use **clear variable names** and drop a **comment** on the tricky lines. Six months from now, that comment is a gift to yourself.
#
# **Total: 100 points** — Part A: 20 · Part B: 30 · Part C: 50.

# %% [markdown]
# ---
# ### ✍️ Before you start
# Put your name in the next cell, then run the setup cell right after it.

# %%
student_name = ""   # <-- type your name between the quotes
print("Submission by:", student_name)

# %%
# === SETUP — run me first! ===
import numpy as np
import pandas as pd
import json, os

# The wine dataset lives in the public course repo, so you can read it straight from the web
# (no download needed) — the same trick we used for data in Session 02.
WINE_URL = "https://raw.githubusercontent.com/cgpan/humd5001_mini/main/assets/wine.csv"
print("pandas", pd.__version__, "| NumPy", np.__version__)
print("Setup complete ✅")

# %% [markdown]
# ---
# ## Part A — Multiple Choice  *(2 points each, 20 total)*
#
# Reason each one out — you should not need to run any code for Part A. When you are done, record your letters in the answer dictionary at the end of this part.

# %% [markdown]
# #### Question A1
# **Difficulty:** ★☆☆☆☆  **Skills:** `Series` vs `DataFrame`
#
# When you pull a single column out of a DataFrame with `df["col"]`, what type do you get back?
#
# - **A.** a `DataFrame`
# - **B.** a `Series`
# - **C.** a `list`
# - **D.** a NumPy array

# %% [markdown]
# #### Question A2
# **Difficulty:** ★☆☆☆☆  **Skills:** `.shape`
#
# A DataFrame `df` has 178 rows and 14 columns. What does `df.shape` return?
#
# - **A.** `(14, 178)`
# - **B.** `(178, 14)`
# - **C.** `178`
# - **D.** `192`

# %% [markdown]
# #### Question A3
# **Difficulty:** ★★★☆☆  **Skills:** `.loc` vs `.iloc` (endpoint)
#
# With a default integer index, how many rows does `df.loc[0:3]` return?
#
# - **A.** `3`
# - **B.** `4`
# - **C.** `0`
# - **D.** the same as `df.iloc[0:3]`

# %% [markdown]
# #### Question A4
# **Difficulty:** ★★★☆☆  **Skills:** combining filters (`&`)
#
# Which line correctly keeps the rows where column `a` is positive **and** column `b` is below 5?
#
# - **A.** `df[(df.a > 0) and (df.b < 5)]`
# - **B.** `df[(df.a > 0) & (df.b < 5)]`
# - **C.** `df[df.a > 0 and df.b < 5]`
# - **D.** `df[df.a > 0 & df.b < 5]`

# %% [markdown]
# #### Question A5
# **Difficulty:** ★★☆☆☆  **Skills:** `value_counts()`
#
# Which method tells you how many times each distinct value appears in a column?
#
# - **A.** `.describe()`
# - **B.** `.value_counts()`
# - **C.** `.groupby()`
# - **D.** `.unique()`

# %% [markdown]
# #### Question A6
# **Difficulty:** ★★★☆☆  **Skills:** `groupby()`
#
# What does `iris.groupby("species")["petal_length"].mean()` give you?
#
# - **A.** one number: the overall mean petal length
# - **B.** the mean petal length **for each species**
# - **C.** every row, sorted by species
# - **D.** an error

# %% [markdown]
# #### Question A7
# **Difficulty:** ★☆☆☆☆  **Skills:** `pd.read_csv`
#
# Which function reads a CSV file (or a URL) into a DataFrame?
#
# - **A.** `pd.open_csv`
# - **B.** `pd.read_csv`
# - **C.** `pd.load_csv`
# - **D.** `pd.csv`

# %% [markdown]
# #### Question A8
# **Difficulty:** ★★☆☆☆  **Skills:** single vs double brackets
#
# What does `df[["alcohol", "hue"]]` return?
#
# - **A.** a `Series`
# - **B.** a `DataFrame` with those two columns
# - **C.** a `list` of two columns
# - **D.** an error

# %% [markdown]
# #### Question A9
# **Difficulty:** ★★★☆☆  **Skills:** counting missing values
#
# Which expression counts the missing (`NaN`) values in **each column** of `df`?
#
# - **A.** `df.isna().sum()`
# - **B.** `df.dropna()`
# - **C.** `df.fillna(0)`
# - **D.** `df.count()`

# %% [markdown]
# #### Question A10
# **Difficulty:** ★★★★☆  **Skills:** `describe()`
#
# A numeric column's `.describe()` reports several statistics. Which of these is **not** among them?
#
# - **A.** the mean
# - **B.** the count
# - **C.** the median (the 50% row)
# - **D.** the mode

# %% [markdown]
# #### ✅ Record your Part A answers
# Fill in the dictionary below so each number points to your chosen letter (for example, `1: "C"`). Yes — this is the **dictionary** skill from Session 01, doing real work.

# %%
my_mcq_answers = {
    1 : "",   # Question A1
    2 : "",   # Question A2
    3 : "",   # Question A3
    4 : "",   # Question A4
    5 : "",   # Question A5
    6 : "",   # Question A6
    7 : "",   # Question A7
    8 : "",   # Question A8
    9 : "",   # Question A9
    10: "",   # Question A10
}
print(my_mcq_answers)

# %% [markdown]
# ---
# ## Part B — Basic Exercises  *(5 points each, 30 total)*
#
# Each drill zooms in on **one** pandas idea. Write your answer in the empty cell under each prompt. Short is fine — focused is the goal.

# %% [markdown]
# #### Exercise B1 — A Series of scores
# **Difficulty:** ★★☆☆☆  **Points:** 5
# **Skills:** `pd.Series`, `.mean()`, `.max()`, boolean filtering
#
# Build a Series of five exam scores with the students' names as the index:
#
# ```python
# scores = pd.Series([88, 92, 79, 95, 84], index=["Ann", "Bob", "Cara", "Dan", "Eve"])
# ```
#
# 1. Print the **average** score, rounded to 1 decimal.
# 2. Print the **highest** score.
# 3. Using a boolean mask, print only the students who scored **above the average**.

# %%
# Your code here

# %% [markdown]
# #### Exercise B2 — A little product table
# **Difficulty:** ★★☆☆☆  **Points:** 5
# **Skills:** `pd.DataFrame`, `.shape`, `.columns`, `.dtypes`
#
# Build this DataFrame from a dictionary:
#
# ```python
# products = pd.DataFrame({
#     "name":     ["pen", "notebook", "eraser", "marker"],
#     "price":    [1.2, 3.5, 0.8, 2.0],
#     "in_stock": [True, True, False, True],
# })
# ```
#
# 1. Print the table's **shape**.
# 2. Print the **column names** as a list.
# 3. Print the **dtype of each column** with `.dtypes` (notice how pandas picked a type per column).

# %%
# Your code here

# %% [markdown]
# #### Exercise B3 — Selecting with .loc and .iloc
# **Difficulty:** ★★★☆☆  **Points:** 5
# **Skills:** `.iloc`, `.loc`, column selection
#
# Here is a small weather table with **letter labels** for its rows:
#
# ```python
# weather = pd.DataFrame({
#     "city":  ["NYC", "LA", "Chicago", "Houston"],
#     "temp":  [55, 72, 48, 80],
#     "humid": [0.6, 0.3, 0.7, 0.5],
# }, index=["a", "b", "c", "d"])
# ```
#
# 1. Print the **first two rows** with `.iloc`.
# 2. Print the `temp` value for the row labeled **`"c"`** with `.loc`.
# 3. Print just the `city` and `temp` columns for **all** rows.

# %%
# Your code here

# %% [markdown]
# #### Exercise B4 — Filtering with two conditions
# **Difficulty:** ★★★☆☆  **Points:** 5
# **Skills:** boolean masks, `&`, `.shape`
#
# ```python
# people = pd.DataFrame({
#     "name":   ["Ann", "Bob", "Cara", "Dan"],
#     "age":    [22, 35, 28, 19],
#     "member": [True, False, True, True],
# })
# ```
#
# 1. Keep only the rows where `age` is **at least 21** *and* `member` is `True`. Combine the two conditions with `&`, and remember the parentheses.
# 2. Print those rows, and print **how many** there are with `.shape[0]`.

# %%
# Your code here

# %% [markdown]
# #### Exercise B5 — Adding a column, then counting
# **Difficulty:** ★★☆☆☆  **Points:** 5
# **Skills:** new column (vectorized), `value_counts()`
#
# ```python
# sales = pd.DataFrame({
#     "product": ["A", "B", "A", "C", "B", "A"],
#     "units":   [3, 1, 2, 5, 4, 1],
#     "price":   [10, 20, 10, 5, 20, 10],
# })
# ```
#
# 1. Add a new column `revenue` equal to `units * price` (one vectorized line — no loop).
# 2. Print the updated table.
# 3. Use `value_counts()` on the `product` column to show how many times each product appears.

# %%
# Your code here

# %% [markdown]
# #### Exercise B6 — Grouping and summarizing
# **Difficulty:** ★★★★☆  **Points:** 5
# **Skills:** `groupby`, `.sum()`, `.mean()`
#
# ```python
# orders = pd.DataFrame({
#     "region": ["East", "West", "East", "West", "East"],
#     "amount": [100, 200, 150, 250, 120],
# })
# ```
#
# 1. Print the **total** `amount` for each region (`groupby` then `.sum()`).
# 2. Print the **average** `amount` for each region (`groupby` then `.mean()`).

# %%
# Your code here

# %% [markdown]
# ---
# ## Part C — Integrated Challenges  *(50 points total)*
#
# Now the fun part: a real dataset, analyzed end to end. Load the **wine** data once in **C1**, then keep using that same `wine` DataFrame through C2–C4. Still no `for`, `if`, or `def` — pandas has you covered.

# %% [markdown]
# #### Exercise C1 — Loading & inspecting — first look at the wine data
# **Difficulty:** ★★★☆☆  **Points:** 12
# **Skills:** `pd.read_csv` (URL), `.shape`, `.columns`, `.head()`, `.describe()`, `value_counts()`
#
# **The setting.** Every analysis starts the same way: load the data and get your bearings. The **wine** dataset holds 178 wines from **three cultivars** (grape varieties), labeled `class_id` 1, 2, or 3, with thirteen chemical measurements each. You already set `WINE_URL` in the setup cell.
#
# 1. Read the CSV with `pd.read_csv(WINE_URL)` into a DataFrame called `wine`.
# 2. Print its **shape** and its **column names** as a list.
# 3. Show the **first 3 rows** with `.head(3)`.
# 4. Use `value_counts()` on the `class_id` column to see how many wines are in each cultivar.
# 5. Print `.describe()` for the `alcohol` column, and print its **mean** rounded to 2 decimals.

# %%
# Your code here

# %% [markdown]
# #### Exercise C2 — Filtering — find the strong, bold wines
# **Difficulty:** ★★★★☆  **Points:** 12
# **Skills:** new column, boolean filtering with `&`, `.shape`, arithmetic
#
# **The setting.** A sommelier wants the full-bodied wines: high alcohol and deep color. This is boolean filtering — the same skill as NumPy masking, now on a real table. *(Uses the `wine` DataFrame from C1.)*
#
# 1. Add a `True`/`False` column `is_strong` that is `True` when `alcohol` is above **13**.
# 2. Filter for the wines that are **both** strong (`alcohol > 13`) **and** deeply colored (`color_intensity > 5`). Print how many there are with `.shape[0]`.
# 3. What **fraction** of all the wines are strong? Divide `wine["is_strong"].sum()` by the total number of rows (`wine.shape[0]`), rounded to 2 decimals.

# %%
# Your code here

# %% [markdown]
# #### Exercise C3 — Grouping — do the cultivars differ?
# **Difficulty:** ★★★★☆  **Points:** 13
# **Skills:** `groupby`, `.mean()`, `sort_values`, `value_counts`
#
# **The setting.** The real question behind this dataset: are the three cultivars chemically different? `groupby` answers it in a couple of lines — split by cultivar, average each measurement, compare. *(Uses the `wine` DataFrame from C1.)*
#
# 1. Group by `class_id` and print the **mean** of `alcohol`, `flavanoids`, and `color_intensity` for each cultivar (select those three columns, then `.mean()`, rounded to 2).
# 2. Which cultivar has the highest average `proline`? Group `proline` by `class_id`, take the mean, and `sort_values(ascending=False)` so the winner is on top.
# 3. Print how many wines are in each cultivar with `value_counts()`.

# %%
# Your code here

# %% [markdown]
# #### Exercise C4 — Capstone — a small end-to-end analysis
# **Difficulty:** ★★★★★  **Points:** 13
# **Skills:** filtering, new column, `groupby`, `set()`, `json.dump`/`json.load`, `os.path.exists`, f-string
#
# **The setting.** Put it all together the way a real analysis flows: subset, summarize, then **save the results** so a later step (or a teammate) can pick them up. This pulls in the file I/O from Session 02 as well. *(Uses the `wine` DataFrame from C1.)*
#
# 1. Add a `True`/`False` column `high_proline` that is `True` when `proline` is above the **mean** `proline`. Print how many wines are high-proline (`.sum()`).
# 2. Pull out just the **cultivar-1** wines (`class_id == 1`) and print their **average alcohol**, rounded to 2.
# 3. Print the **mean alcohol per cultivar** with `groupby`.
# 4. Count the distinct cultivars with `len(set(wine["class_id"]))`. Build a small **summary dictionary** with the number of wines, the number of cultivars, the mean alcohol, and the count of high-proline wines. **Write it** to `wine_summary.json` with `json.dump`, read it back with `json.load`, and confirm the file exists with `os.path.exists`.
# 5. Finish with an f-string, for example: `The wine set has 178 wines across 3 cultivars, averaging 13.0% alcohol.`

# %%
# Your code here

# %% [markdown]
# ---
# ## 📤 Submission
#
# 1. In Colab, run *Runtime ▸ Run all* and make sure every cell finishes **without errors**.
# 2. Double-check that your Part A answer dictionary is filled in.
# 3. Save or download your notebook (*File ▸ Download ▸ .ipynb*, or share your Colab link) and turn it in on **Canvas** as instructed.
#
# > 💡 Stuck? Re-open `03_Pandas.ipynb` — and keep `01`–`02` handy for the strings, dicts, and NumPy pieces. Every tool you need is demonstrated there.
